# %%
import pandas as pd

# %%
df=pd .DataFrame([[1,2,3,4],[5,6,7,8],[2,6,3,2]],columns=['a','b','c','d'],index=['x','y','z'])

# %%
df.head(1)
# Out:
#    a  b  c  d
# x  1  2  3  4

# %%
df.tail(1)
# Out:
#    a  b  c  d
# z  2  6  3  2

# %%
print(df.columns)
print(df.index.to_list())
# Out:
# Index(['a', 'b', 'c', 'd'], dtype='object')
# ['x', 'y', 'z']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, x to z
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   a       3 non-null      int64
#  1   b       3 non-null      int64
#  2   c       3 non-null      int64
#  3   d       3 non-null      int64
# dtypes: int64(4)
# memory usage: 120.0+ bytes

# %%
df.describe()
# Out:
#               a         b         c         d
# count  3.000000  3.000000  3.000000  3.000000
# mean   2.666667  4.666667  4.333333  4.666667
# std    2.081666  2.309401  2.309401  3.055050
# min    1.000000  2.000000  3.000000  2.000000
# 25%    1.500000  4.000000  3.000000  3.000000
# 50%    2.000000  6.000000  3.000000  4.000000
# 75%    3.500000  6.000000  5.000000  6.000000
# max    5.000000  6.000000  7.000000  8.000000

# %%
df[['a','b']].nunique()
# Out:
# a    3
# b    2
# dtype: int64

# %%
df.shape
# Out:
# (3, 4)

# %% [markdown]
# # Load dataset
# ## Accessing dataset

# %%
data=pd.read_csv('loan.csv')

# %%
data.head()
display(data)
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
data.sample(10,random_state=1)
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 533  LP002729    Male      No          1      Graduate            No
# 544  LP002757  Female     Yes          0  Not Graduate            No
# 41   LP001120    Male      No          0      Graduate            No
# 148  LP001519  Female      No          0      Graduate            No
# 111  LP001387  Female     Yes          0      Graduate           NaN
# 293  LP001945  Female      No        NaN      Graduate            No
# 435  LP002393  Female     NaN        NaN      Graduate            No
# 407  LP002314  Female      No          0  Not Graduate            No
# 311  LP002004    Male      No          0  Not Graduate            No
# 23   LP001050     NaN     Yes          2  Not Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 533            11250                0.0       196.0             360.0
# ...

# %%
#loc,iloc

data.loc[[0,1,2]]
# Out:
#     Loan_ID Gender Married Dependents Education Self_Employed  \
# 0  LP001002   Male      No          0  Graduate            No
# 1  LP001003   Male     Yes          1  Graduate            No
# 2  LP001005   Male     Yes          0  Graduate           Yes
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# 2             1.0         Urban           Y

# %%
data.loc[5:13, ['Gender','Married']]
# Out:
#    Gender Married
# 5    Male     Yes
# 6    Male     Yes
# 7    Male     Yes
# 8    Male     Yes
# 9    Male     Yes
# 10   Male     Yes
# 11   Male     Yes
# 12   Male     Yes
# 13   Male      No

# %%
data.iloc[5:13, [1,2]]
# Out:
#    Gender Married
# 5    Male     Yes
# 6    Male     Yes
# 7    Male     Yes
# 8    Male     Yes
# 9    Male     Yes
# 10   Male     Yes
# 11   Male     Yes
# 12   Male     Yes

# %%
#data.index=data['Gender']

# %%
data.loc[1:13,['Married','Dependents']]
# Out:
#    Married Dependents
# 1      Yes          1
# 2      Yes          0
# 3      Yes          0
# 4       No          0
# 5      Yes          2
# 6      Yes          0
# 7      Yes         3+
# 8      Yes          2
# 9      Yes          1
# 10     Yes          2
# 11     Yes          2
# 12     Yes          2
# 13      No          0

# %%
data.loc['Male','CoapplicantIncome']=2

# %%
data.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0           5849.0                0.0         NaN             360.0
# 1           4583.0             1508.0       128.0             360.0
# 2           3000.0                0.0        66.0             360.0
# 3           2583.0             2358.0       120.0             360.0
# 4           6000.0                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
data.at[0,'Loan_ID']
# Out:
# 'LP001002'

# %%
data.sort_values('ApplicantIncome',ascending=False)
# Out:
#        Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 409   LP002317    Male     Yes         3+      Graduate            No
# 333   LP002101    Male     Yes          0      Graduate           NaN
# 171   LP001585     NaN     Yes         3+      Graduate            No
# 155   LP001536    Male     Yes         3+      Graduate            No
# 185   LP001640    Male     Yes          0      Graduate           Yes
# ...        ...     ...     ...        ...           ...           ...
# 500   LP002603  Female      No          0      Graduate            No
# 600   LP002949  Female      No         3+      Graduate           NaN
# 468   LP002502  Female     Yes          2  Not Graduate           NaN
# 216   LP001722    Male     Yes          0      Graduate            No
# Male       NaN     NaN     NaN        NaN           NaN           NaN
#
#       ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
#for index,row in data.iterrows():
    #print(index)
    #print(row['Loan_ID'])
   # print('\n\n')

# %% [markdown]
# # Filtering the data

# %%
data.loc[(data['LoanAmount']>200)&(data['Education']=='Not Graduate'),['Loan_ID','Gender','Dependents']]
# Out:
#       Loan_ID  Gender Dependents
# 250  LP001835    Male          0
# 253  LP001843    Male          1
# 412  LP002328    Male          0
# 493  LP002582  Female          0

# %%
#data[data['Property_Area'].str.contains('Rural|Urban'),regex=False]

# %%
data[data['Property_Area'].isin(['Urban'])&(data['Education'].str.startswith('Not Graduate'))]
data.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0           5849.0                0.0         NaN             360.0
# 1           4583.0             1508.0       128.0             360.0
# 2           3000.0                0.0        66.0             360.0
# 3           2583.0             2358.0       120.0             360.0
# 4           6000.0                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
#data.query('Education'=='Graduate')

# %% [markdown]
# # Adding and Removing Columns

# %%
data_new=data.copy()
data_new['price']=499

# %%
data.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0           5849.0                0.0         NaN             360.0
# 1           4583.0             1508.0       128.0             360.0
# 2           3000.0                0.0        66.0             360.0
# 3           2583.0             2358.0       120.0             360.0
# 4           6000.0                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
import numpy as np
data_new['new price']=np.where(data_new['Property_Area']=='Urban',499,399)

# %%
data_new.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0           5849.0                0.0         NaN             360.0
# 1           4583.0             1508.0       128.0             360.0
# 2           3000.0                0.0        66.0             360.0
# 3           2583.0             2358.0       120.0             360.0
# 4           6000.0                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status  price  new price
# 0             1.0         Urban           Y    499        499
# ...

# %%
data_new.drop(columns=['price'],inplace=True)

# %%
data_new.rename(columns={'new price':'price'},inplace=True)

# %%
data_new.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0           5849.0                0.0         NaN             360.0
# 1           4583.0             1508.0       128.0             360.0
# 2           3000.0                0.0        66.0             360.0
# 3           2583.0             2358.0       120.0             360.0
# 4           6000.0                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status  price
# 0             1.0         Urban           Y    499
# 1             1.0         Rural           N    399
# ...

# %%
data_new['first_name']=data_new['Education'].str.split(' ').str[0]

# %%
data_new
# Out:
#        Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0     LP001002    Male      No          0      Graduate            No
# 1     LP001003    Male     Yes          1      Graduate            No
# 2     LP001005    Male     Yes          0      Graduate           Yes
# 3     LP001006    Male     Yes          0  Not Graduate            No
# 4     LP001008    Male      No          0      Graduate            No
# ...        ...     ...     ...        ...           ...           ...
# 610   LP002979    Male     Yes         3+      Graduate            No
# 611   LP002983    Male     Yes          1      Graduate            No
# 612   LP002984    Male     Yes          2      Graduate            No
# 613   LP002990  Female      No          0      Graduate           Yes
# Male       NaN     NaN     NaN        NaN           NaN           NaN
#
#       ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
#bios_new['born datetime']=pd.todatetime(bios_new['born_date'])
#bios_new['born_year']=bios_new['born_datetime'].dt.year
#bios_new[['name','born_year']]

# %%
#data_new.to_csv('./desktop/data_new.csv',index=False)

# %%
data['ApplicantIncome_cat']=data['ApplicantIncome'].apply(lambda x:'bad' if x<2000 else ('average' if x<5000 else 'good'))

# %%
data.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0           5849.0                0.0         NaN             360.0
# 1           4583.0             1508.0       128.0             360.0
# 2           3000.0                0.0        66.0             360.0
# 3           2583.0             2358.0       120.0             360.0
# 4           6000.0                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status ApplicantIncome_cat
# 0             1.0         Urban           Y                good
# ...

# %% [markdown]
# # Handling Null value

# %%
data.fillna(data['LoanAmount'].mean())
# Out:
#          Loan_ID      Gender     Married  Dependents     Education  \
# 0       LP001002        Male          No           0      Graduate
# 1       LP001003        Male         Yes           1      Graduate
# 2       LP001005        Male         Yes           0      Graduate
# 3       LP001006        Male         Yes           0  Not Graduate
# 4       LP001008        Male          No           0      Graduate
# ...          ...         ...         ...         ...           ...
# 610     LP002979        Male         Yes          3+      Graduate
# 611     LP002983        Male         Yes           1      Graduate
# 612     LP002984        Male         Yes           2      Graduate
# 613     LP002990      Female          No           0      Graduate
# Male  146.412162  146.412162  146.412162  146.412162    146.412162
#
#      Self_Employed  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# 0               No      5849.000000                0.0  146.412162
# ...

# %%
data['units']=data['Credit_History'].interpolate()
data.head(10)
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
# 5  LP001011   Male     Yes          2      Graduate           Yes
# 6  LP001013   Male     Yes          0  Not Graduate            No
# 7  LP001014   Male     Yes         3+      Graduate            No
# 8  LP001018   Male     Yes          2      Graduate            No
# 9  LP001020   Male     Yes          1      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0           5849.0                0.0         NaN             360.0
# 1           4583.0             1508.0       128.0             360.0
# ...

# %%
data.dropna(subset=['units'])
# Out:
#        Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0     LP001002    Male      No          0      Graduate            No
# 1     LP001003    Male     Yes          1      Graduate            No
# 2     LP001005    Male     Yes          0      Graduate           Yes
# 3     LP001006    Male     Yes          0  Not Graduate            No
# 4     LP001008    Male      No          0      Graduate            No
# ...        ...     ...     ...        ...           ...           ...
# 610   LP002979    Male     Yes         3+      Graduate            No
# 611   LP002983    Male     Yes          1      Graduate            No
# 612   LP002984    Male     Yes          2      Graduate            No
# 613   LP002990  Female      No          0      Graduate           Yes
# Male       NaN     NaN     NaN        NaN           NaN           NaN
#
#       ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
data[data['LoanAmount'].notna()]#isna
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# 5    LP001011    Male     Yes          2      Graduate           Yes
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %% [markdown]
#  # aggregating data

# %%
data['Education'].value_counts()
# Out:
# Education
# Graduate        480
# Not Graduate    134
# Name: count, dtype: int64

# %%
data[data['Education']=='Graduate']['Self_Employed'].value_counts()
# Out:
# Self_Employed
# No     389
# Yes     65
# Name: count, dtype: int64

# %%
data.groupby(['Dependents'])['Credit_History'].sum()
# Out:
# Dependents
# 0     271.0
# 1      76.0
# 2      81.0
# 3+     37.0
# Name: Credit_History, dtype: float64

# %%
pivot=data.pivot(columns='Property_Area',index='Loan_ID',values='ApplicantIncome')

# %%
pivot
# Out:
# Property_Area  NaN   Rural  Semiurban   Urban
# Loan_ID
# NaN            NaN     NaN        NaN     NaN
# LP001002       NaN     NaN        NaN  5849.0
# LP001003       NaN  4583.0        NaN     NaN
# LP001005       NaN     NaN        NaN  3000.0
# LP001006       NaN     NaN        NaN  2583.0
# ...            ...     ...        ...     ...
# LP002978       NaN  2900.0        NaN     NaN
# LP002979       NaN  4106.0        NaN     NaN
# LP002983       NaN     NaN        NaN  8072.0
# LP002984       NaN     NaN        NaN  7583.0
# LP002990       NaN     NaN     4583.0     NaN
#
# [615 rows x 4 columns]

# %%
#.shift(),rank(),.cumsum(),.rolling()
